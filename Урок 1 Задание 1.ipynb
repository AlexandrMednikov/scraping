# %% [markdown]
# 1
#
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json

rep = requests.get("https://api.github.com/users/AlexandrMednikov/repos")
with open("data1.json", 'w') as f:
    json.dump(rep.json(), f)


for i in rep.json():
    print(i['name'])
# Out:
# -Python-Data-Science-Numpy-Matplotlib-Scikit-learn
# algoritms
# course-project-on-predicting-real-estate-prices
# hometask
# les-1
# lesson1
# Linal
# SQL-project
# Theory-of-Probability-and-Mathematical-Statistics

# %% [markdown]
# 2
#
# Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
rep = requests.get("https://api.vk.com/method/groups.get?user_id=200620510&extended=1&v=5.81&access_token=vk1.a.EJEqi1zgXPHMqCiHIHl90t8wViR8GeSB4DnxWv5HBehxa0Ovzlr8Lh6W4oNpTuTMDBpsEOgs0FB0n3b3_IrH9iBgRDA_XgrkcIBcO-u0BeUym6xllDDJ_iADWHkhfGAhTF9KLQgEULJ38bxQFbF2DKuPayVWlXPbKPadyMQ7LqMLNqmS_x7R1UIPP28pEJYJ")
rep.json()
# Out:
# {'response': {'count': 28,
#   'items': [{'id': 29534144,
#     'name': 'Лентач',
#     'screen_name': 'lentach',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun1.userapi.com/sun1-99/s/v1/ig2/NJX63LTNdmXBUW_yFpBmQvMEfOGi8J73kH_ptJt5pHgGfNKw-E3ULV-dqFqUDK4U0aMDFtW_rrlFIXoGyz-fnXPW.jpg?size=50x50&quality=96&crop=6,5,1098,1098&ava=1',
#     'photo_100': 'https://sun1.userapi.com/sun1-99/s/v1/ig2/iRiMLOH5QMnQGdCkBe3R-a5KX4sNFxmFCQlWTUBCvz9l-1IQYFQ-NX6oCj7Y50cnEWH2pegb4f3e2JiuHh4Gp-e3.jpg?size=100x100&quality=96&crop=6,5,1098,1098&ava=1',
#     'photo_200': 'https://sun1.userapi.com/sun1-99/s/v1/ig2/XWj74PoM5DFm-fuKJLr5PuHWBwIRzCqeoYQCWq1lNrHNyeajTejepe3ugPfocQ38G3R6c-9W0tt71Us_rS1y6YkX.jpg?size=200x200&quality=96&crop=6,5,1098,1098&ava=1'},
#    {'id': 153838717,
#     'name': 'БАРБЕР НИКОЛАЙ ГЕНЕРАЛОВ. ОБУЧЕНИЕ ЦИРЮЛЬНИКОВ.',
#     'screen_name': 'generalov_team',
#     'is_closed': 0,
#     'type': 'group',
# ...

# %%
with open("data2.json", 'w') as f:
    json.dump(rep.json(), f)
